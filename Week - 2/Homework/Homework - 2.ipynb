# %% [markdown]
# ### Q1. Install MLflow

# %% [markdown]
# To get started with MLflow you'll need to install the MLflow Python package.
#
# For this we recommend creating a separate Python environment, for example, you can use conda environments, and then install the package there with pip or conda.
#
# Once you installed the package, run the command mlflow --version and check the output.
#
# What's the version that you have?

# %% [markdown]
# ```bash mlflow --verison ```

# %% [markdown]
# The version of MLFlow is version 2.22.0

# %% [markdown]
# ### Q2. Download and preprocess the data

# %% [markdown]
# The data is in path  C:\Users\Siddharth\Downloads\MLOps ZoomCamp\Week - 2\Homework\Data.
#
# So the command to save the output of the preprocess of the data in the Output Folder will be
#
# python preprocess_data.py --raw_data_path "C:\Users\Siddharth\Downloads\MLOps ZoomCamp\Week - 2\Homework\Data" --dest_path "./output"

# %% [markdown]
# We see that it generated 4 pickle files . The train validation and test pickles files along with the dictonary vectorizer

# %% [markdown]
# ### Q3. Train a model with autolog

# %% [markdown]
# python train.py --data_path ./output
#
# mlflow ui --backend-store-uri sqlite:///mlflow.db
#
# This results in a model with min_samples_split parameter being 2

# %% [markdown]
# ### Q4. Launch the tracking server locally

# %% [markdown]
# default-artifact-root
#
# Tells MLflow that all artifacts generated by runs (when not overridden at the experiment level) should be stored in a local directory named artifacts relative to where you run the command.

# %% [markdown]
# ### Q5. Tune model hyperparameters

# %% [markdown]
# python hpo.py --data_path ./output   value 5.335

# %% [markdown]
# ### Q6. Promote the best model to the model registry

# %% [markdown]
# python register_model.py value 5.5674
